# %%
import pandas as pd
import numpy as np
import pylab as pl
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

from util.methods import Methods
from util.passing import Passing
from util.stat import FantasyStats

from cost_functions import CostFunction
pd.set_option('display.width', 300)

# Update this to the latest year that data is available
score_year = 2014
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8869e9245f2a> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import pylab as pl
#       4 from sklearn import ensemble
#       5 from sklearn import datasets
#
# ImportError: No module named pylab

# %%
func = Methods()
passing = Passing(2002, score_year)
passing.compile_data()
passing.construct_feature_vector()
df=passing.get_passing_data()
df[passing.dep_var + passing.feature_vector].describe()
# Out:
#        y_future_rank      y_top5  y_sqrt_future_rank  y_future_points  y_sqr_future_points          RK       is_qb  games_played     n_years  td_per_game       ...        r_att_comp  r_yards_game  r_att_game  avg_career_rank  previous_rank1_clean  previous_rank2_clean  previous_rank3_clean  \
# count     430.000000  600.000000          430.000000       430.000000           430.000000  600.000000  600.000000    600.000000  600.000000   600.000000       ...        600.000000    600.000000  600.000000       600.000000            600.000000            600.000000            600.000000
# mean       28.379070    0.071667            5.005862       369.553488            17.490105   30.498333    0.988333      9.488333    4.506667     1.077665       ...          1.698865    190.329798   27.880667        30.091111             29.443333             29.520000             29.926667
# std        17.291631    0.258150            1.824322       272.428534             7.987371   17.329759    0.107470      5.136520    2.883947     0.641810       ...          0.351945     76.949163   10.437621        14.700527             17.053685             17.015644             17.056949
# min         1.000000    0.000000            1.000000         4.000000             2.000000    1.000000    0.000000      1.000000    1.000000     0.000000       ...          1.000000      3.000000    0.071429         2.333333              1.000000              1.000000              1.000000
# 25%        13.000000    0.000000            3.605551       113.250000            10.641417   15.750000    1.000000      5.000000    2.000000     0.666667       ...          1.572238    144.645833   23.964286        18.333333             15.000000             15.000000             16.000000
# 50%        27.000000    0.000000            5.196152       332.500000            18.234577   30.500000    1.000000      9.000000    4.000000     1.000000       ...          1.663935    198.958333   29.483333        29.916667             29.000000             29.000000             30.000000
# 75%        43.000000    0.000000            6.557439       604.750000            24.591626   45.250000    1.000000     15.000000    6.000000     1.533333       ...          1.783246    243.767857   34.750000        41.333333             44.000000             43.250000             44.000000
# max        60.000000    1.000000            7.745967      1077.000000            32.817678   60.000000    1.000000     17.000000   13.000000     3.437500       ...          9.000000    475.000000   77.000000        59.833333             60.000000             60.000000             60.000000
#
#        previous_rank4_clean  previous_rank5_clean  lst_rank_delta
# count            600.000000            600.000000      600.000000
# mean              30.368333             30.790000        0.459016
# std               17.024366             16.985486        2.946869
# min                1.000000              1.000000       -0.944444
# 25%               16.000000             16.750000       -0.220810
# 50%               30.000000             30.000000        0.000000
# 75%               45.000000             45.000000        0.441993
# max               60.000000             60.000000       58.000000
#
# [8 rows x 24 columns]

# %%
stat = FantasyStats(df, score_year)
stat.build_train_valid_score(60)
df_train = stat.get_df_train()
print len(df_train)

df_valid = stat.get_df_valid()
print len(df_valid)

df_score = stat.get_df_score()
print len(df_score)
df_score
# Out:
# 324
# 216
# 60
#       index  RK                  PLAYER     TEAM  COMP  ATT   PCT   YDS    AVG  LONG         ...           points_td  points_total  points_yds10 points_yds25 lst_rank_delta  y_future_rank  y_future_points  y_top5  y_sqrt_future_rank  y_sqr_future_points
# year                                                                                         ...
# 2014      0   1          Drew Brees, QB       NO   456  659  69.2  4952   7.51    69         ...                 198           857           495          198      -0.500000            NaN              NaN       0                 NaN                  NaN
# 2014      1   2  Ben Roethlisberger, QB      PIT   408  608  67.1  4952   8.15    94         ...                 192           867           495          198      -0.777778            NaN              NaN       0                 NaN                  NaN
# 2014      2   3         Andrew Luck, QB      IND   380  616  61.7  4761   7.73    80         ...                 240           874           476          190      -0.769231            NaN              NaN       0                 NaN                  NaN
# 2014      3   4      Peyton Manning, QB      DEN   395  597  66.2  4727   7.92    86         ...                 234           866           473          189       3.000000            NaN              NaN       0                 NaN                  NaN
# 2014      4   5           Matt Ryan, QB      ATL   415  628  66.1  4694   7.48    79         ...                 168           797           469          188       0.250000            NaN              NaN       0                 NaN                  NaN
# 2014      5   6         Eli Manning, QB      NYG   379  601  63.1  4410   7.34    80         ...                 180           769           441          176      -0.571429            NaN              NaN       0                 NaN                  NaN
# 2014      6   7       Aaron Rodgers, QB       GB   341  520  65.6  4381   8.43    80         ...                 228           831           438          175      -0.720000            NaN              NaN       0                 NaN                  NaN
# 2014      7   8       Philip Rivers, QB       SD   379  570  66.5  4286   7.52    59         ...                 186           750           429          171       0.600000            NaN              NaN       0                 NaN                  NaN
# 2014      8   9    Matthew Stafford, QB      DET   363  602  60.3  4257   7.07    73         ...                 132           704           426          170       2.000000            NaN              NaN       0                 NaN                  NaN
# 2014      9  10           Tom Brady, QB       NE   373  582  64.1  4109   7.06    69         ...                 198           755           411          164       0.666667            NaN              NaN       0                 NaN                  NaN
# 2014     10  11      Ryan Tannehill, QB      MIA   392  590  66.4  4045   6.86    50         ...                 162           705           405          162       0.100000            NaN              NaN       0                 NaN                  NaN
# 2014     11  12          Joe Flacco, QB      BAL   344  554  62.1  3986    7.2    80         ...                 162           696           399          159       0.090909            NaN              NaN       0                 NaN                  NaN
# 2014     12  13          Jay Cutler, QB      CHI   370  561    66  3812    6.8    74         ...                 168           665           381          152      -0.434783            NaN              NaN       0                 NaN                  NaN
# 2014     13  14           Tony Romo, QB      DAL   304  435  69.9  3705   8.52    68         ...                 204           705           371          148       0.166667            NaN              NaN       0                 NaN                  NaN
# 2014     14  15      Russell Wilson, QB      SEA   285  452  63.1  3475   7.69    80         ...                 120           593           348          139      -0.062500            NaN              NaN       0                 NaN                  NaN
# 2014     15  16         Andy Dalton, QB      CIN   309  481  64.2  3398   7.06    81         ...                 114           556           340          136       1.285714            NaN              NaN       0                 NaN                  NaN
# 2014     54  55      Johnny Manziel, QB      CLE    18   35  51.4   175      5    32         ...                   0            21            18            7       0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     55  56        Chase Daniel, QB       KC    16   28  57.1   157   5.61    30         ...                   0            22            16            6       0.098039            NaN              NaN       0                 NaN                  NaN
# 2014     56  57        Matt McGloin, QB      OAK    12   19  63.2   129   6.79    29         ...                   6            20            13            5       0.500000            NaN              NaN       0                 NaN                  NaN
# 2014     57  58          Tom Savage, QB      HOU    10   19  52.6   127   6.68    35         ...                   0            16            13            5       0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     58  59        Logan Thomas, QB      ARI     1    9  11.1    81      9    81         ...                   6            17             8            3       0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     59  60        Mohamed Sanu, WR      CIN     3    3   100    79  26.33    50         ...                   6            17             8            3       0.111111            NaN              NaN       0                 NaN                  NaN
#
# [60 rows x 52 columns]

# %% [markdown]
# ### Train the Gradient Boosted Regression

# %%
params = {'n_estimators': 500,
          'max_depth': 3,
          'min_samples_split': 2,
          'learning_rate': 0.04,
          'loss': 'ls',
          'verbose': 1}

dependent_variable = passing.dep_var[2]
print dependent_variable

stat.train_gbr_fulL_sample(dependent_variable, params, passing.feature_vector)

clfr = stat.get_gbr_result()
print "\n"
stat.feature_importance(clfr, passing.feature_vector)
# Out:
# y_sqrt_future_rank
#       Iter       Train Loss   Remaining Time
#          1           3.1806            0.52s
#          2           3.0501            0.45s
#          3           2.9302            0.43s
#          4           2.8179            0.43s
#          5           2.7147            0.45s
#          6           2.6175            0.46s
#          7           2.5280            0.48s
#          8           2.4444            0.50s
#          9           2.3663            0.51s
#         10           2.2943            0.52s
#         20           1.7686            0.50s
#         30           1.4779            0.47s
#         40           1.3066            0.44s
#         50           1.1864            0.41s
#         60           1.0998            0.39s
#         70           1.0279            0.38s
#         80           0.9787            0.37s
#         90           0.9358            0.36s
#        100           0.8993            0.34s
#        200           0.5985            0.24s
#        300           0.4009            0.16s
#        400           0.2808            0.08s
#        500           0.1914            0.00s
#
#
# is_qb               4.49916911332
# games_played        19.0800254559
# percent_comp        27.0487577344
# previous_rank3_clean28.0171082065
# previous_rank5_clean30.4251923739
# previous_rank4_clean36.0610256012
# n_years             37.9938091584
# previous_rank1_clean39.7886287702
# previous_rank2_clean44.766654827
# r_att_comp          47.2397325852
# RK                  48.1068399536
# comp_per_game       75.3002056577
# int_per_game        76.1187157935
# avg_career_rank     76.6293608913
# r_yards_game        78.8692659371
# sack_per_game       80.5206438237
# lst_rank_delta      83.0752267375
# r_att_game          87.6392083645
# td_per_game         88.618966325
# log_yards           100.0

# %% [markdown]
# ### Train the Sqrt Points Gradient Boosted Regression

# %%
params = {'n_estimators': 600,
          'max_depth': 3,
          'min_samples_split': 2,
          'learning_rate': 0.04,
          'loss': 'ls',
          'verbose': 1}

dependent_variable = passing.dep_var[4]
print dependent_variable

stat.train_gbr_fulL_sample(dependent_variable, params, passing.feature_vector)

clfr2 = stat.get_gbr_result()
print "\n"
stat.feature_importance(clfr2, passing.feature_vector)
# Out:
# y_sqr_future_points
#       Iter       Train Loss   Remaining Time
#          1          61.0565            0.65s
#          2          58.6642            0.62s
#          3          56.4526            0.68s
#          4          54.4306            0.69s
#          5          52.5498            0.67s
#          6          50.8324            0.66s
#          7          49.2196            0.65s
#          8          47.7040            0.64s
#          9          46.2688            0.64s
#         10          44.9405            0.64s
#         20          35.3894            0.56s
#         30          29.9504            0.57s
#         40          26.5771            0.54s
#         50          24.2529            0.53s
#         60          22.6784            0.51s
#         70          21.3912            0.49s
#         80          20.3519            0.48s
#         90          19.4362            0.46s
#        100          18.5189            0.45s
#        200          12.6083            0.30s
#        300           8.0687            0.23s
#        400           5.3186            0.15s
#        500           3.5858            0.08s
#        600           2.4819            0.00s
#
#
# is_qb               5.58920582942
# games_played        13.8499127069
# previous_rank5_clean25.0370092404
# n_years             28.8190878321
# percent_comp        29.1811488775
# previous_rank3_clean31.7924892246
# previous_rank1_clean36.8484477326
# r_att_comp          45.8565109925
# previous_rank4_clean51.1551678241
# RK                  53.7442808379
# previous_rank2_clean54.9892248281
# r_yards_game        56.9044484393
# int_per_game        59.23171806
# comp_per_game       60.3584062554
# sack_per_game       61.6678193542
# lst_rank_delta      72.274533895
# avg_career_rank     78.9976639133
# td_per_game         80.5772704294
# log_yards           81.4791835102
# r_att_game          100.0

# %% [markdown]
# ### Train the Gradient Boosted Classifier

# %%
params = {'n_estimators': 400, 
          'learning_rate': 0.04,
          'random_state': 0,
          'max_depth': 3,
          'min_samples_split': 2,
          'verbose': 1, 
          'random_state': 0}
 

dependent_variable = passing.dep_var[1]
print dependent_variable
stat.train_gbc_full_sample(dependent_variable, params, passing.feature_vector)
print "\n"
clfc = stat.get_gbc_result()
stat.feature_importance(clfc, passing.feature_vector)
# Out:
# y_top5
#       Iter       Train Loss   Remaining Time
#          1           0.4808            0.67s
#          2           0.4561            0.69s
#          3           0.4373            0.69s
#          4           0.4216            0.69s
#          5           0.4087            0.68s
#          6           0.3977            0.67s
#          7           0.3871            0.66s
#          8           0.3757            0.65s
#          9           0.3653            0.64s
#         10           0.3572            0.63s
#         20           0.2894            0.61s
#         30           0.2430            0.56s
#         40           0.2084            0.53s
#         50           0.1863            0.50s
#         60           0.1737            0.47s
#         70           0.1631            0.44s
#         80           0.1509            0.42s
#         90           0.1410            0.40s
#        100           0.1323            0.39s
#        200           0.0621            0.26s
#        300           0.0325            0.12s
#        400           0.0176            0.00s
#
#
# is_qb               0.0
# games_played        6.50970427866
# previous_rank5_clean23.1525882277
# previous_rank4_clean24.504741657
# previous_rank3_clean24.8341430108
# percent_comp        27.5099127449
# RK                  36.7610257332
# sack_per_game       39.2255404457
# r_att_game          39.7800848828
# n_years             41.6976724714
# previous_rank1_clean42.6273125896
# previous_rank2_clean48.7128187143
# int_per_game        49.3534411246
# r_att_comp          57.4207322138
# comp_per_game       57.7968917333
# avg_career_rank     68.1203986724
# r_yards_game        75.7924694722
# lst_rank_delta      84.8255146213
# td_per_game         98.7440970727
# log_yards           100.0

# %% [markdown]
# ### Validation sample (boosted reg 1)

# %%
df_combined = stat.score_train_and_validation_reg(clfr, passing.feature_vector, True)
df_combined[df_combined.year==score_year-1].sort('p_rank', ascending=True)[['PLAYER', 'TEAM', 'y_future_rank', 'p_rank']][:15]
# Out:
#                      PLAYER TEAM  y_future_rank  p_rank
# 92           Drew Brees, QB   NO              1       1
# 104      Peyton Manning, QB  DEN              4       2
# 248  Ben Roethlisberger, QB  PIT              2       3
# 433           Matt Ryan, QB  ATL              5       4
# 314         Andrew Luck, QB  IND              3       5
# 11        Philip Rivers, QB   SD              8       6
# 120       Aaron Rodgers, QB   GB              7       7
# 15          Eli Manning, QB  NYG              6       8
# 505           Tom Brady, QB   NE             10       9
# 275    Matthew Stafford, QB  DET              9      10
# 382           Tony Romo, QB  DAL             14      11
# 458          Jay Cutler, QB  CHI             13      12
# 148          Joe Flacco, QB  BAL             12      13
# 320      Ryan Tannehill, QB  MIA             11      14
# 72            Jeff Tuel, QB  BUF            NaN      15

# %% [markdown]
# ### Validation sample (boosted reg 2)

# %%
df_combined = stat.score_train_and_validation_reg(clfr2, passing.feature_vector, False)
df_combined[df_combined.year==score_year-1].sort('p_rank', ascending=True)[['PLAYER', 'TEAM', 'y_future_rank', 'p_rank']][:15]
# Out:
#                      PLAYER TEAM  y_future_rank  p_rank
# 92           Drew Brees, QB   NO              1       1
# 104      Peyton Manning, QB  DEN              4       2
# 120       Aaron Rodgers, QB   GB              7       3
# 11        Philip Rivers, QB   SD              8       4
# 433           Matt Ryan, QB  ATL              5       5
# 314         Andrew Luck, QB  IND              3       6
# 505           Tom Brady, QB   NE             10       7
# 382           Tony Romo, QB  DAL             14       8
# 248  Ben Roethlisberger, QB  PIT              2       9
# 15          Eli Manning, QB  NYG              6      10
# 275    Matthew Stafford, QB  DET              9      11
# 277         Andy Dalton, QB  CIN             16      12
# 148          Joe Flacco, QB  BAL             12      13
# 320      Ryan Tannehill, QB  MIA             11      14
# 31       Russell Wilson, QB  SEA             15      15

# %% [markdown]
# ### Validation sample (boosted classifier 1)

# %%
df_combined = stat.score_train_and_validation_class(clfc, passing.feature_vector, False)
df_combined[df_combined.year==score_year-1].sort('p_rank', ascending=True)[['PLAYER', 'TEAM', 'y_future_rank', 'p_rank']][:15]
# Out:
#                      PLAYER TEAM  y_future_rank  p_rank
# 92           Drew Brees, QB   NO              1       1
# 104      Peyton Manning, QB  DEN              4       2
# 433           Matt Ryan, QB  ATL              5       3
# 314         Andrew Luck, QB  IND              3       4
# 248  Ben Roethlisberger, QB  PIT              2       5
# 277         Andy Dalton, QB  CIN             16       6
# 382           Tony Romo, QB  DAL             14       7
# 458          Jay Cutler, QB  CHI             13       8
# 11        Philip Rivers, QB   SD              8       9
# 275    Matthew Stafford, QB  DET              9      10
# 555        Sam Bradford, QB  STL            NaN      11
# 505           Tom Brady, QB   NE             10      12
# 190         Josh McCown, QB  CHI             28      13
# 120       Aaron Rodgers, QB   GB              7      14
# 557          Cam Newton, QB  CAR             21      15

# %% [markdown]
# ### Prediction Sample (all regs)

# %%
def _final_order_score(df):
    score = float(df['pred_boost_reg1']) * 0.4 +\
            float(df['pred_boost_reg2']) * 0.4 +\
            float(df['pred_classifier1']) * 0.2
    return score

# %%
df_score_reg = pd.DataFrame(stat.score_pred_reg(clfr, passing.feature_vector, True))
df_score_reg.set_index('PLAYER', inplace=True, drop=False)
df_score_reg.rename(columns={'p_rank': 'pred_boost_reg1'}, inplace=True)

df_score_reg2 = pd.DataFrame(stat.score_pred_reg(clfr2, passing.feature_vector, False))
df_score_reg2.set_index('PLAYER', inplace=True, drop=False)
df_score_reg2.rename(columns={'p_rank': 'pred_boost_reg2'}, inplace=True)


df_score_class = pd.DataFrame(stat.score_pred_class(clfc, passing.feature_vector, False))
df_score_class.set_index('PLAYER', inplace=True, drop=False)
df_score_class.rename(columns={'p_rank': 'pred_classifier1'}, inplace=True)

df_score_all = df_score_reg.join(df_score_class['pred_classifier1'])
df_score_all = df_score_all.join(df_score_reg2['pred_boost_reg2'])

df_score_all['final_order_score'] = df_score_all.apply(_final_order_score, axis=1)
df_score_all.sort('final_order_score', ascending=True, inplace=True)
df_score_all.reset_index(inplace=True, drop=True)
df_score_all.rename(columns={'RK': '%s Rank' % score_year}, inplace=True)

df_score_all[['PLAYER', 'TEAM', '%s Rank' % score_year, 'final_order_score', 'pred_boost_reg1', 'pred_boost_reg2', 'pred_classifier1']]
# Out:
#                     PLAYER     TEAM  2014 Rank  final_order_score  pred_boost_reg1  pred_boost_reg2  pred_classifier1
# 0            Matt Ryan, QB      ATL          5                3.0                4                2               3.0
# 1           Drew Brees, QB       NO          1                3.2                1                5               4.0
# 2       Peyton Manning, QB      DEN          4                3.8                2                4               7.0
# 3        Philip Rivers, QB       SD          8                4.6                3                1              15.0
# 4       Ryan Tannehill, QB      MIA         11                6.2                7                3              11.0
# 5   Ben Roethlisberger, QB      PIT          2                6.6                8                6               5.0
# 6          Eli Manning, QB      NYG          6                8.4                9                7              10.0
# 7            Tom Brady, QB       NE         10                9.6                5               15               8.0
# 8           Joe Flacco, QB      BAL         12                9.8               12               12               1.0
# 9          Andrew Luck, QB      IND          3               11.0               11                8              17.0
# 10       Aaron Rodgers, QB       GB          7               11.2               10               10              16.0
# 11           Tony Romo, QB      DAL         14               12.4                6               19              12.0
# 12    Matthew Stafford, QB      DET          9               12.6               14               13               9.0
# 13          Jay Cutler, QB      CHI         13               13.6               16               11              14.0
# 14         Andy Dalton, QB      CIN         16               15.2               17               20               2.0
# 15          Cam Newton, QB      CAR         21               15.6               19                9              22.0
