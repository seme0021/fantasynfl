# %%
import pandas as pd
import numpy as np
import pylab as pl
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

from util.methods import Methods
from util.rushing import Rushing
from util.stat import FantasyStats

from cost_functions import CostFunction
pd.set_option('display.width', 300)

# Update this to the latest year that data is available
score_year = 2014

# %%
func = Methods()
rushing = Rushing(2002, score_year)
rushing.compile_data()
rushing.construct_feature_vector()
df=rushing.get_receiving_data()
df[rushing.dep_var + rushing.feature_vector].describe()
# Out:
#        y_future_rank      y_top5  y_sqrt_future_rank  y_future_points  y_sqr_future_points          RK  is_runner  games_played     n_years  td_per_game     ...       r_1d_game  avg_career_rank  previous_rank1_clean  previous_rank2_clean  previous_rank3_clean  previous_rank4_clean  \
# count     386.000000  600.000000          386.000000       386.000000           386.000000  600.000000  600.00000    600.000000  600.000000   600.000000     ...      600.000000       600.000000            600.000000            600.000000            600.000000            600.000000
# mean       27.769430    0.136667            4.934721       147.080311            11.785742   30.481667    0.93000     13.731667    3.445000     0.379219     ...        2.710101        30.697500             29.296667             29.671667             30.735000             31.570000
# std        17.549668    0.343782            1.851171        70.103421             2.863184   17.341594    0.25536      2.357738    2.243218     0.268775     ...        1.179631        14.204365             16.954185             16.926055             16.821307             16.736845
# min         1.000000    0.000000            1.000000        37.000000             6.082763    1.000000    0.00000      5.000000    1.000000     0.000000     ...        0.666667         1.000000              1.000000              1.000000              1.000000              1.000000
# 25%        12.000000    0.000000            3.464102        87.000000             9.327379   15.000000    1.00000     13.000000    1.000000     0.166667     ...        1.750000        19.000000             15.000000             15.000000             16.000000             17.000000
# 50%        26.000000    0.000000            5.099020       138.500000            11.768583   30.500000    1.00000     15.000000    3.000000     0.333333     ...        2.620192        30.583333             30.000000             31.000000             32.000000             33.000000
# 75%        43.000000    0.000000            6.557439       197.000000            14.035669   45.250000    1.00000     15.000000    5.000000     0.533333     ...        3.533333        41.333333             43.000000             43.000000             44.000000             45.000000
# max        60.000000    1.000000            7.745967       423.000000            20.566964   60.000000    1.00000     16.000000   11.000000     1.750000     ...        6.687500        60.000000             60.000000             60.000000             60.000000             60.000000
#
#        previous_rank5_clean  lst_rank_delta    r_td_rec   log_yards
# count            600.000000      600.000000  600.000000  600.000000
# mean              32.430000        0.586529    0.029791    6.511033
# std               16.651242        2.745789    0.018671    0.484555
# min                1.000000       -0.963636    0.000000    5.379897
# 25%               18.000000       -0.163288    0.016461    6.102551
# 50%               34.000000        0.000000    0.027027    6.496775
# 75%               46.000000        0.416667    0.040228    6.932448
# max               60.000000       42.000000    0.111111    7.648263
#
# [8 rows x 26 columns]

# %%
stat = FantasyStats(df, score_year)
stat.build_train_valid_score(60)
df_train = stat.get_df_train()
print len(df_train)

df_valid = stat.get_df_valid()
print len(df_valid)

df_score = stat.get_df_score()
print len(df_score)
df_score
# Out:
# 331
# 210
# 59
#       index  Year  RK                PLAYER         TEAM  ATT   YDS YDS/A  LONG  20+         ...           points_td points_total  points_yds10  points_yds25  lst_rank_delta  y_future_rank  y_future_points  y_top5  y_sqrt_future_rank  y_sqr_future_points
# year                                                                                         ...
# 2014      1  2014   1    DeMarco Murray, RB          DAL  392  1845   4.7    51   15         ...                  78          337           185            74       -0.900000            NaN              NaN       0                 NaN                  NaN
# 2014     44  2014  44    Ahmad Bradshaw, RB          IND   90   425   4.7    29    3         ...                  12           72            43            17        1.750000            NaN              NaN       0                 NaN                  NaN
# 2014     45  2014  45   Latavius Murray, RB          OAK   82   424   5.2    90    4         ...                  12           71            42            17        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     46  2014  46     Blake Bortles, QB          JAX   56   419   7.5    34    7         ...                   0           59            42            17        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     47  2014  47        Jonas Gray, RB           NE   89   412   4.6    20    1         ...                  30           87            41            16        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     48  2014  48      Bobby Rainey, RB           TB   94   406   4.3    31    4         ...                   6           63            41            16        0.170732            NaN              NaN       0                 NaN                  NaN
# 2014     49  2014  49      Shonn Greene, RB          TEN   94   392   4.2    52    2         ...                  12           67            39            16        2.500000            NaN              NaN       0                 NaN                  NaN
# 2014     50  2014  50      Shane Vereen, RB           NE   96   391   4.1    19    0         ...                  12           67            39            16        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     51  2014  52    Khiry Robinson, RB           NO   76   362   4.8    62    2         ...                  18           68            36            14        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     52  2014  53     Daniel Herron, RB          IND   78   351   4.5    49    1         ...                   6           55            35            14        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     53  2014  54     Joseph Randle, RB          DAL   51   343   6.7    65    3         ...                  18           66            34            14        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     54  2014  55     Stevan Ridley, RB           NE   94   340   3.6    43    1         ...                  12           60            34            14        1.619048            NaN              NaN       0                 NaN                  NaN
# 2014     55  2014  56          Ben Tate, RB  CLE/MIN/PIT  106   333   3.1    25    1         ...                  24           70            33            13        1.434783            NaN              NaN       0                 NaN                  NaN
# 2014     56  2014  57      James Starks, RB           GB   85   333   3.9    41    3         ...                  12           58            33            13        0.325581            NaN              NaN       0                 NaN                  NaN
# 2014     57  2014  58       Carlos Hyde, RB           SF   83   333     4    28    1         ...                  24           70            33            13        0.000000            NaN              NaN       0                 NaN                  NaN
# 2014     58  2014  59      Ryan Mathews, RB           SD   74   330   4.5    32    3         ...                  18           64            33            13        7.428571            NaN              NaN       0                 NaN                  NaN
# 2014     59  2014  60    Darren Sproles, RB          PHI   57   329   5.8    49    2         ...                  36           82            33            13        0.818182            NaN              NaN       0                 NaN                  NaN
#
# [59 rows x 51 columns]

# %% [markdown]
# ### Train the Gradient Boosted Regression

# %%
params = {'n_estimators': 500,
          'max_depth': 3,
          'min_samples_split': 2,
          'learning_rate': 0.04,
          'loss': 'ls',
          'verbose': 1}

dependent_variable = rushing.dep_var[2]
print dependent_variable

stat.train_gbr_fulL_sample(dependent_variable, params, rushing.feature_vector)

clfr = stat.get_gbr_result()
print "\n"
stat.feature_importance(clfr, rushing.feature_vector)
# Out:
# y_sqrt_future_rank
#       Iter       Train Loss   Remaining Time
#          1           3.3378            0.56s
#          2           3.2648            0.47s
#          3           3.1909            0.47s
#          4           3.1225            0.50s
#          5           3.0601            0.51s
#          6           3.0000            0.49s
#          7           2.9456            0.49s
#          8           2.8952            0.50s
#          9           2.8452            0.51s
#         10           2.7994            0.51s
#         20           2.4446            0.46s
#         30           2.2188            0.43s
#         40           2.0486            0.40s
#         50           1.9103            0.38s
#         60           1.8116            0.35s
#         70           1.7406            0.34s
#         80           1.6743            0.32s
#         90           1.6133            0.31s
#        100           1.5607            0.30s
#        200           1.0784            0.20s
#        300           0.7252            0.13s
#        400           0.4944            0.07s
#        500           0.3574            0.00s
#
#
# is_runner           3.48327342485
# previous_rank5_clean6.93088414859
# games_played        9.31756983784
# previous_rank3_clean11.7883871847
# previous_rank4_clean12.7375411723
# n_years             14.1204505554
# RK                  15.2992528822
# previous_rank2_clean17.0873512952
# r_fum_game          17.8445799449
# td_per_game         26.4130951034
# avg_career_rank     28.5998756607
# r_1d_game           36.5625440909
# r_yards_game        40.9092127805
# log_yards           41.4839757721
# lst_rank_delta      41.6754527712
# r_20p_game          42.7132844272
# previous_rank1_clean43.2058802168
# log_long            55.2841035623
# att_per_game        55.3608653765
# r_td_rec            56.7150037571
# r_yds_att           100.0

# %% [markdown]
# ### Train the Sqrt Points Gradient Boosted Regression

# %%
params = {'n_estimators': 500,
          'max_depth': 3,
          'min_samples_split': 2,
          'learning_rate': 0.04,
          'loss': 'ls',
          'verbose': 1}

dependent_variable = rushing.dep_var[4]
print dependent_variable

stat.train_gbr_fulL_sample(dependent_variable, params, rushing.feature_vector)

clfr2 = stat.get_gbr_result()
print "\n"
stat.feature_importance(clfr2, rushing.feature_vector)
# Out:
# y_sqr_future_points
#       Iter       Train Loss   Remaining Time
#          1           7.9808            0.59s
#          2           7.8047            0.57s
#          3           7.6393            0.55s
#          4           7.4851            0.54s
#          5           7.3387            0.55s
#          6           7.2017            0.53s
#          7           7.0729            0.53s
#          8           6.9497            0.52s
#          9           6.8362            0.53s
#         10           6.7262            0.52s
#         20           5.8776            0.54s
#         30           5.3109            0.49s
#         40           4.9027            0.46s
#         50           4.5844            0.42s
#         60           4.3057            0.41s
#         70           4.0856            0.39s
#         80           3.9535            0.37s
#         90           3.7928            0.36s
#        100           3.6472            0.35s
#        200           2.3578            0.22s
#        300           1.5117            0.14s
#        400           0.9986            0.07s
#        500           0.6853            0.00s
#
#
# is_runner           2.68972479079
# previous_rank5_clean11.7869912086
# previous_rank4_clean12.6482401921
# previous_rank3_clean12.7115835937
# games_played        15.711004246
# RK                  20.3092266539
# previous_rank2_clean22.6030041662
# n_years             26.0466135972
# td_per_game         33.073149717
# avg_career_rank     40.0222882599
# previous_rank1_clean40.2861000139
# r_fum_game          41.2714148048
# lst_rank_delta      43.576120858
# att_per_game        49.1705755671
# r_1d_game           54.4681754324
# r_20p_game          57.1389142338
# r_yards_game        61.6808767696
# log_long            64.861545502
# log_yards           64.8939549983
# r_td_rec            66.5728879182
# r_yds_att           100.0

# %%
Train the Gradient Boosted Classifier

# %%
params = {'n_estimators': 400, 
          'learning_rate': 0.04,
          'random_state': 0,
          'max_depth': 3,
          'min_samples_split': 2,
          'verbose': 1, 
          'random_state': 0}
 

dependent_variable = rushing.dep_var[1]
print dependent_variable
stat.train_gbc_full_sample(dependent_variable, params, rushing.feature_vector)
print "\n"
clfc = stat.get_gbc_result()
stat.feature_importance(clfc, rushing.feature_vector)
# Out:
# y_top5
#       Iter       Train Loss   Remaining Time
#          1           0.7780            0.94s
#          2           0.7618            0.75s
#          3           0.7462            0.70s
#          4           0.7329            0.68s
#          5           0.7196            0.66s
#          6           0.7089            0.66s
#          7           0.6994            0.64s
#          8           0.6900            0.64s
#          9           0.6821            0.62s
#         10           0.6725            0.60s
#         20           0.6101            0.58s
#         30           0.5653            0.56s
#         40           0.5319            0.53s
#         50           0.5055            0.51s
#         60           0.4803            0.48s
#         70           0.4632            0.45s
#         80           0.4458            0.43s
#         90           0.4320            0.41s
#        100           0.4212            0.39s
#        200           0.2996            0.24s
#        300           0.2114            0.12s
#        400           0.1467            0.00s
#
#
# is_runner           1.84799924039
# games_played        8.79804182914
# previous_rank1_clean13.5485107449
# previous_rank2_clean17.9901425383
# n_years             19.1855926164
# previous_rank3_clean20.8959914618
# previous_rank4_clean21.620085512
# previous_rank5_clean24.2187976922
# RK                  34.2443035358
# r_fum_game          36.1212517458
# td_per_game         36.2480320311
# lst_rank_delta      50.7600263365
# log_long            54.129254433
# r_1d_game           67.884771714
# r_td_rec            68.2367150239
# r_20p_game          68.660838084
# avg_career_rank     70.423098721
# r_yds_att           77.2616136193
# att_per_game        78.8434796567
# r_yards_game        82.2597918297
# log_yards           100.0

# %% [markdown]
# ### Validation sample (boosted reg 1)

# %%
df_combined = stat.score_train_and_validation_reg(clfr, rushing.feature_vector, True)
df_combined[df_combined.year==score_year-1].sort('p_rank', ascending=True)[['PLAYER', 'TEAM', 'y_future_rank', 'p_rank']][:15]
# Out:
#                         PLAYER TEAM  y_future_rank  p_rank
# 554           LeSean McCoy, RB  PHI              3       1
# 16          DeMarco Murray, RB  DAL              1       2
# 468         Marshawn Lynch, RB  SEA              4       3
# 297             Matt Forte, RB  CHI             12       4
# 11            Le'Veon Bell, RB  PIT              2       5
# 579           Arian Foster, RB  HOU              6       6
# 69              Eddie Lacy, RB   GB              7       7
# 510         Jamaal Charles, RB   KC             13       8
# 81              Frank Gore, RB   SF              9       9
# 376          Alfred Morris, RB  WSH             11      10
# 207               Ray Rice, RB  BAL            NaN      11
# 598           Lamar Miller, RB  MIA             10      12
# 190     Maurice Jones-Drew, RB  JAX            NaN      13
# 169            Joique Bell, RB  DET             15      14
# 454  BenJarvus Green-Ellis, RB  CIN            NaN      15

# %% [markdown]
# ### Validation sample (boosted reg 2)

# %%
df_combined = stat.score_train_and_validation_reg(clfr2, rushing.feature_vector, False)
df_combined[df_combined.year==score_year-1].sort('p_rank', ascending=True)[['PLAYER', 'TEAM', 'y_future_rank', 'p_rank']][:15]
# Out:
#                         PLAYER TEAM  y_future_rank  p_rank
# 16          DeMarco Murray, RB  DAL              1       1
# 468         Marshawn Lynch, RB  SEA              4       2
# 554           LeSean McCoy, RB  PHI              3       3
# 579           Arian Foster, RB  HOU              6       4
# 69              Eddie Lacy, RB   GB              7       5
# 297             Matt Forte, RB  CHI             12       6
# 376          Alfred Morris, RB  WSH             11       7
# 510         Jamaal Charles, RB   KC             13       8
# 11            Le'Veon Bell, RB  PIT              2       9
# 598           Lamar Miller, RB  MIA             10      10
# 251        Knowshon Moreno, RB  DEN            NaN      11
# 454  BenJarvus Green-Ellis, RB  CIN            NaN      12
# 81              Frank Gore, RB   SF              9      13
# 229            Mark Ingram, RB   NO             14      14
# 190     Maurice Jones-Drew, RB  JAX            NaN      15

# %% [markdown]
# ### Validation sample (boosted classifier 1)

# %%
df_combined = stat.score_train_and_validation_class(clfc, rushing.feature_vector, False)
df_combined[df_combined.year==score_year-1].sort('p_rank', ascending=True)[['PLAYER', 'TEAM', 'y_future_rank', 'p_rank']][:15]
# Out:
#                     PLAYER TEAM  y_future_rank  p_rank
# 554       LeSean McCoy, RB  PHI              3       1
# 579       Arian Foster, RB  HOU              6       2
# 69          Eddie Lacy, RB   GB              7       3
# 468     Marshawn Lynch, RB  SEA              4       4
# 16      DeMarco Murray, RB  DAL              1       5
# 81          Frank Gore, RB   SF              9       6
# 11        Le'Veon Bell, RB  PIT              2       7
# 598       Lamar Miller, RB  MIA             10       8
# 297         Matt Forte, RB  CHI             12       9
# 510     Jamaal Charles, RB   KC             13      10
# 47           Zac Stacy, RB  STL            NaN      11
# 223       Ryan Mathews, RB   SD             59      12
# 90   DeAngelo Williams, RB  CAR            NaN      13
# 328      Chris Johnson, RB  TEN             25      14
# 120           Ben Tate, RB  HOU             56      15

# %%
def _final_order_score(df):
    score = float(df['pred_boost_reg1']) * 0.4 +\
            float(df['pred_boost_reg2']) * 0.5 +\
            float(df['pred_classifier1']) * 0.1
    return score

# %%
df_score_reg = pd.DataFrame(stat.score_pred_reg(clfr, rushing.feature_vector, True))
df_score_reg.set_index('PLAYER', inplace=True, drop=False)
df_score_reg.rename(columns={'p_rank': 'pred_boost_reg1'}, inplace=True)

df_score_reg2 = pd.DataFrame(stat.score_pred_reg(clfr2, rushing.feature_vector, False))
df_score_reg2.set_index('PLAYER', inplace=True, drop=False)
df_score_reg2.rename(columns={'p_rank': 'pred_boost_reg2'}, inplace=True)


df_score_class = pd.DataFrame(stat.score_pred_class(clfc, rushing.feature_vector, False))
df_score_class.set_index('PLAYER', inplace=True, drop=False)
df_score_class.rename(columns={'p_rank': 'pred_classifier1'}, inplace=True)

df_score_all = df_score_reg.join(df_score_class['pred_classifier1'])
df_score_all = df_score_all.join(df_score_reg2['pred_boost_reg2'])

df_score_all['final_order_score'] = df_score_all.apply(_final_order_score, axis=1)
df_score_all.sort('final_order_score', ascending=True, inplace=True)
df_score_all.reset_index(inplace=True, drop=True)
df_score_all.rename(columns={'RK': '%s Rank' % score_year}, inplace=True)

df_score_all[['PLAYER', 'TEAM', '%s Rank' % score_year, 'final_order_score', 'pred_boost_reg1', 'pred_boost_reg2', 'pred_classifier1']]
# Out:
#                   PLAYER         TEAM  2014 Rank  final_order_score  pred_boost_reg1  pred_boost_reg2  pred_classifier1
# 0       LeSean McCoy, RB          PHI          3                1.7                1                2                 3
# 1       Arian Foster, RB          HOU          6                1.9                2                1                 6
# 2       Le'Veon Bell, RB          PIT          2                2.9                3                3                 2
# 3        Jeremy Hill, RB          CIN          8                5.3                6                5                 4
# 4     Marshawn Lynch, RB          SEA          4                6.5                7                4                17
# 5         Eddie Lacy, RB           GB          7                7.8                8                9                 1
# 6       Lamar Miller, RB          MIA         10                7.9                4               10                13
# 7         Frank Gore, RB           SF          9               10.7               15                7                12
# 8     DeMarco Murray, RB          DAL          1               11.8               13                6                36
# 9        Chris Ivory, RB          NYJ         18               14.5               11               12                41
# 10    Jamaal Charles, RB           KC         13               16.6               16               19                 7
# 11  Jonathan Stewart, RB          CAR         19               16.6               21                8                42
# 12       Matt Asiata, RB          MIN         32               17.5               20               11                40
# 13     Chris Johnson, RB          NYJ         25               17.7                9               22                31
# 14    Ronnie Hillman, RB          DEN         42               18.1               14               18                35
# 15     C.J. Anderson, RB          DEN         16               18.6               18               21                 9
# 16        Jonas Gray, RB           NE         47               18.8               17               13                55
# 17       Doug Martin, RB           TB         40               19.3               10               29                 8
# 18    Khiry Robinson, RB           NO         52               20.4               23               15                37
# 19        Matt Forte, RB          CHI         12               20.9               24               17                28
# 20    Isaiah Crowell, RB          CLE         29               21.2                5               33                27
# 21    Steven Jackson, RB          ATL         22               24.1               38               14                19
# 22   Jerick McKinnon, RB          MIN         35               25.1               19               31                20
# 23       Joique Bell, RB          DET         15               26.1               34               23                10
# 24    Justin Forsett, RB          BAL          5               27.1               22               28                43
# 25     Bishop Sankey, RB          TEN         33               27.2               27               25                39
# 26    Ahmad Bradshaw, RB          IND         44               27.8               32               20                50
# 27    Russell Wilson, QB          SEA         17               28.4               30               26                34
# 28       Carlos Hyde, RB           SF         58               28.4               37               16                56
# 29   Rashad Jennings, RB          NYG         27               29.4               28               27                47
# 30     Stevan Ridley, RB           NE         55               30.1               31               24                57
# 31    Andre Williams, RB          NYG         21               30.1               25               37                16
# 32      Ryan Mathews, RB           SD         59               30.2               29               32                26
# 33         Tre Mason, RB          STL         20               30.8               26               38                14
# 34     Terrance West, RB          CLE         24               31.7               33               36                 5
# 35   Darren McFadden, RB          OAK         36               31.7               12               43                54
# 36       Mark Ingram, RB           NO         14               32.1               40               30                11
# 37    Branden Oliver, RB           SD         30               36.6               43               34                24
# 38        Cam Newton, QB          CAR         34               37.2               36               35                53
# 39     Alfred Morris, RB          WSH         11               39.4               35               45                29
# 40     Daniel Herron, RB          IND         53               39.4               39               40                38
# 41   Latavius Murray, RB          OAK         45               40.2               44               41                21
# 42   Andre Ellington, RB          ARI         26               40.8               45               42                18
# 43   Giovani Bernard, RB          CIN         23               44.7               42               47                44
# 44  Trent Richardson, RB          IND         39               44.9               46               44                45
# 45      Shonn Greene, RB          TEN         49               45.9               54               39                48
# 46  Colin Kaepernick, QB           SF         28               46.2               48               49                25
# 47      Fred Jackson, RB          BUF         38               46.9               47               46                51
# 48      Bobby Rainey, RB           TB         48               47.6               41               56                32
# 49   Denard Robinson, RB          JAX         31               48.5               52               51                22
# 50     Blake Bortles, QB          JAX         46               48.7               56               48                23
# 51       Knile Davis, RB           KC         41               48.9               51               54                15
# 52     Joseph Randle, RB          DAL         54               50.6               50               52                46
# 53       Alfred Blue, RB          HOU         37               51.1               57               50                33
# 54    Darren Sproles, RB          PHI         60               52.0               49               53                59
# 55      Boobie Dixon, RB          BUF         43               52.7               53               57                30
# 56          Ben Tate, RB  CLE/MIN/PIT         56               55.3               55               55                58
# 57      James Starks, RB           GB         57               57.1               58               58                49
# 58      Shane Vereen, RB           NE         50               58.3               59               59                52
